# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.14.0

# %%
NUM_WORDS = 10000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # Create an all-zero matrix of shape (len(sequences), dimension)
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # set specific indices of results[i] to 1s
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %%
baseline_model = keras.Sequential([
        # 'input_shape' is only required here so that '.summary' works
        keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
        keras.layers.Dense(16, activation=tf.nn.relu),
        keras.layers.Dense(1, activation=tf.nn.sigmoid)
    ])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                        metrics=['accuracy', 'binary_crossentropy'])
baseline_model.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0812 12:55:21.841171 140269329020736 deprecation.py:506] From /home/aakash01/.local/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0812 12:55:22.079812 140269329020736 deprecation.py:323] From /home/aakash01/.local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 5s - loss: 0.4496 - acc: 0.8145 - binary_crossentropy: 0.4496 - val_loss: 0.3057 - val_acc: 0.8835 - val_binary_crossentropy: 0.3057
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.2261 - acc: 0.9174 - binary_crossentropy: 0.2261 - val_loss: 0.2837 - val_acc: 0.8882 - val_binary_crossentropy: 0.2837
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.1667 - acc: 0.9419 - binary_crossentropy: 0.1667 - val_loss: 0.3031 - val_acc: 0.8799 - val_binary_crossentropy: 0.3031
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.1358 - acc: 0.9538 - binary_crossentropy: 0.1358 - val_loss: 0.3508 - val_acc: 0.8672 - val_binary_crossentropy: 0.3508
# Epoch 5/20
# 25000/25000 - 3s - loss: 0.1116 - acc: 0.9628 - binary_crossentropy: 0.1116 - val_loss: 0.3562 - val_acc: 0.8708 - val_binary_crossentropy: 0.3562
# Epoch 6/20
# 25000/25000 - 3s - loss: 0.0907 - acc: 0.9721 - binary_crossentropy: 0.0907 - val_loss: 0.3898 - val_acc: 0.8675 - val_binary_crossentropy: 0.3898
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.0738 - acc: 0.9785 - binary_crossentropy: 0.0738 - val_loss: 0.4303 - val_acc: 0.8644 - val_binary_crossentropy: 0.4303
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.0616 - acc: 0.9830 - binary_crossentropy: 0.0616 - val_loss: 0.4748 - val_acc: 0.8604 - val_binary_crossentropy: 0.4748
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.0480 - acc: 0.9884 - binary_crossentropy: 0.0480 - val_loss: 0.5213 - val_acc: 0.8594 - val_binary_crossentropy: 0.5213
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.0391 - acc: 0.9918 - binary_crossentropy: 0.0391 - val_loss: 0.5729 - val_acc: 0.8574 - val_binary_crossentropy: 0.5729
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.0300 - acc: 0.9947 - binary_crossentropy: 0.0300 - val_loss: 0.6231 - val_acc: 0.8548 - val_binary_crossentropy: 0.6231
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.0223 - acc: 0.9967 - binary_crossentropy: 0.0223 - val_loss: 0.6728 - val_acc: 0.8541 - val_binary_crossentropy: 0.6728
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.0168 - acc: 0.9984 - binary_crossentropy: 0.0168 - val_loss: 0.7204 - val_acc: 0.8524 - val_binary_crossentropy: 0.7204
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.0123 - acc: 0.9991 - binary_crossentropy: 0.0123 - val_loss: 0.7701 - val_acc: 0.8506 - val_binary_crossentropy: 0.7701
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.0092 - acc: 0.9997 - binary_crossentropy: 0.0092 - val_loss: 0.8102 - val_acc: 0.8520 - val_binary_crossentropy: 0.8102
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.0071 - acc: 0.9999 - binary_crossentropy: 0.0071 - val_loss: 0.8464 - val_acc: 0.8506 - val_binary_crossentropy: 0.8464
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.0056 - acc: 0.9999 - binary_crossentropy: 0.0056 - val_loss: 0.8812 - val_acc: 0.8504 - val_binary_crossentropy: 0.8812
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.0045 - acc: 1.0000 - binary_crossentropy: 0.0045 - val_loss: 0.9136 - val_acc: 0.8499 - val_binary_crossentropy: 0.9136
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.0037 - acc: 1.0000 - binary_crossentropy: 0.0037 - val_loss: 0.9442 - val_acc: 0.8499 - val_binary_crossentropy: 0.9442
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.0031 - acc: 1.0000 - binary_crossentropy: 0.0031 - val_loss: 0.9726 - val_acc: 0.8496 - val_binary_crossentropy: 0.9726

# %%
smaller_model = keras.Sequential([
        keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
        keras.layers.Dense(4, activation=tf.nn.relu),
        keras.layers.Dense(1, activation=tf.nn.sigmoid)
    ])

smaller_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 2s - loss: 0.6227 - acc: 0.6172 - binary_crossentropy: 0.6227 - val_loss: 0.5609 - val_acc: 0.7205 - val_binary_crossentropy: 0.5609
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.5096 - acc: 0.8013 - binary_crossentropy: 0.5096 - val_loss: 0.5019 - val_acc: 0.8078 - val_binary_crossentropy: 0.5019
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.4539 - acc: 0.8726 - binary_crossentropy: 0.4539 - val_loss: 0.4740 - val_acc: 0.8393 - val_binary_crossentropy: 0.4740
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.4168 - acc: 0.9073 - binary_crossentropy: 0.4168 - val_loss: 0.4538 - val_acc: 0.8615 - val_binary_crossentropy: 0.4538
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.3867 - acc: 0.9259 - binary_crossentropy: 0.3867 - val_loss: 0.4434 - val_acc: 0.8590 - val_binary_crossentropy: 0.4434
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.3532 - acc: 0.9407 - binary_crossentropy: 0.3532 - val_loss: 0.4115 - val_acc: 0.8780 - val_binary_crossentropy: 0.4115
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.3120 - acc: 0.9535 - binary_crossentropy: 0.3120 - val_loss: 0.3841 - val_acc: 0.8790 - val_binary_crossentropy: 0.3841
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.2626 - acc: 0.9596 - binary_crossentropy: 0.2626 - val_loss: 0.3521 - val_acc: 0.8778 - val_binary_crossentropy: 0.3521
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.1994 - acc: 0.9638 - binary_crossentropy: 0.1994 - val_loss: 0.3194 - val_acc: 0.8780 - val_binary_crossentropy: 0.3194
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.1534 - acc: 0.9664 - binary_crossentropy: 0.1534 - val_loss: 0.3107 - val_acc: 0.8794 - val_binary_crossentropy: 0.3107
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.1318 - acc: 0.9700 - binary_crossentropy: 0.1318 - val_loss: 0.3257 - val_acc: 0.8766 - val_binary_crossentropy: 0.3257
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.1176 - acc: 0.9727 - binary_crossentropy: 0.1176 - val_loss: 0.3378 - val_acc: 0.8745 - val_binary_crossentropy: 0.3378
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.1060 - acc: 0.9762 - binary_crossentropy: 0.1060 - val_loss: 0.3541 - val_acc: 0.8722 - val_binary_crossentropy: 0.3541
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.0961 - acc: 0.9788 - binary_crossentropy: 0.0961 - val_loss: 0.3679 - val_acc: 0.8712 - val_binary_crossentropy: 0.3679
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.0877 - acc: 0.9808 - binary_crossentropy: 0.0877 - val_loss: 0.3935 - val_acc: 0.8672 - val_binary_crossentropy: 0.3935
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.0803 - acc: 0.9830 - binary_crossentropy: 0.0803 - val_loss: 0.3971 - val_acc: 0.8680 - val_binary_crossentropy: 0.3971
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.0732 - acc: 0.9854 - binary_crossentropy: 0.0732 - val_loss: 0.4161 - val_acc: 0.8666 - val_binary_crossentropy: 0.4161
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.0676 - acc: 0.9874 - binary_crossentropy: 0.0676 - val_loss: 0.4415 - val_acc: 0.8626 - val_binary_crossentropy: 0.4415
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.0625 - acc: 0.9889 - binary_crossentropy: 0.0625 - val_loss: 0.4493 - val_acc: 0.8624 - val_binary_crossentropy: 0.4493
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.0580 - acc: 0.9907 - binary_crossentropy: 0.0580 - val_loss: 0.4702 - val_acc: 0.8618 - val_binary_crossentropy: 0.4702

# %%
bigger_model = keras.models.Sequential([
        keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
        keras.layers.Dense(512, activation=tf.nn.relu),
        keras.layers.Dense(1, activation=tf.nn.sigmoid)
    ])

bigger_model.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=['accuracy', 'binary_crossentropy'])

bigger_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data,
                                  train_labels,
                                  epochs=20, batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 4s - loss: 0.3408 - acc: 0.8553 - binary_crossentropy: 0.3408 - val_loss: 0.3030 - val_acc: 0.8748 - val_binary_crossentropy: 0.3030
# Epoch 2/20
# 25000/25000 - 4s - loss: 0.1419 - acc: 0.9486 - binary_crossentropy: 0.1419 - val_loss: 0.3307 - val_acc: 0.8730 - val_binary_crossentropy: 0.3307
# Epoch 3/20
# 25000/25000 - 4s - loss: 0.0453 - acc: 0.9870 - binary_crossentropy: 0.0453 - val_loss: 0.4657 - val_acc: 0.8666 - val_binary_crossentropy: 0.4657
# Epoch 4/20
# 25000/25000 - 4s - loss: 0.0072 - acc: 0.9987 - binary_crossentropy: 0.0072 - val_loss: 0.6159 - val_acc: 0.8658 - val_binary_crossentropy: 0.6159
# Epoch 5/20
# 25000/25000 - 4s - loss: 0.0011 - acc: 0.9999 - binary_crossentropy: 0.0011 - val_loss: 0.7243 - val_acc: 0.8684 - val_binary_crossentropy: 0.7243
# Epoch 6/20
# 25000/25000 - 4s - loss: 7.9458e-04 - acc: 1.0000 - binary_crossentropy: 7.9458e-04 - val_loss: 0.7447 - val_acc: 0.8702 - val_binary_crossentropy: 0.7447
# Epoch 7/20
# 25000/25000 - 4s - loss: 1.5751e-04 - acc: 1.0000 - binary_crossentropy: 1.5751e-04 - val_loss: 0.7810 - val_acc: 0.8707 - val_binary_crossentropy: 0.7810
# Epoch 8/20
# 25000/25000 - 4s - loss: 1.0304e-04 - acc: 1.0000 - binary_crossentropy: 1.0304e-04 - val_loss: 0.8101 - val_acc: 0.8707 - val_binary_crossentropy: 0.8101
# Epoch 9/20
# 25000/25000 - 4s - loss: 7.6313e-05 - acc: 1.0000 - binary_crossentropy: 7.6313e-05 - val_loss: 0.8314 - val_acc: 0.8711 - val_binary_crossentropy: 0.8314
# Epoch 10/20
# 25000/25000 - 4s - loss: 6.0312e-05 - acc: 1.0000 - binary_crossentropy: 6.0312e-05 - val_loss: 0.8495 - val_acc: 0.8711 - val_binary_crossentropy: 0.8495
# Epoch 11/20
# 25000/25000 - 4s - loss: 4.8957e-05 - acc: 1.0000 - binary_crossentropy: 4.8957e-05 - val_loss: 0.8663 - val_acc: 0.8712 - val_binary_crossentropy: 0.8663
# Epoch 12/20
# 25000/25000 - 4s - loss: 4.0922e-05 - acc: 1.0000 - binary_crossentropy: 4.0922e-05 - val_loss: 0.8798 - val_acc: 0.8711 - val_binary_crossentropy: 0.8798
# Epoch 13/20
# 25000/25000 - 4s - loss: 3.4564e-05 - acc: 1.0000 - binary_crossentropy: 3.4564e-05 - val_loss: 0.8922 - val_acc: 0.8715 - val_binary_crossentropy: 0.8922
# Epoch 14/20
# 25000/25000 - 4s - loss: 2.9716e-05 - acc: 1.0000 - binary_crossentropy: 2.9716e-05 - val_loss: 0.9044 - val_acc: 0.8713 - val_binary_crossentropy: 0.9044
# Epoch 15/20
# 25000/25000 - 4s - loss: 2.5777e-05 - acc: 1.0000 - binary_crossentropy: 2.5777e-05 - val_loss: 0.9151 - val_acc: 0.8713 - val_binary_crossentropy: 0.9151
# Epoch 16/20
# 25000/25000 - 4s - loss: 2.2631e-05 - acc: 1.0000 - binary_crossentropy: 2.2631e-05 - val_loss: 0.9255 - val_acc: 0.8712 - val_binary_crossentropy: 0.9255
# Epoch 17/20
# 25000/25000 - 4s - loss: 1.9977e-05 - acc: 1.0000 - binary_crossentropy: 1.9977e-05 - val_loss: 0.9350 - val_acc: 0.8712 - val_binary_crossentropy: 0.9350
# Epoch 18/20
# 25000/25000 - 4s - loss: 1.7762e-05 - acc: 1.0000 - binary_crossentropy: 1.7762e-05 - val_loss: 0.9440 - val_acc: 0.8711 - val_binary_crossentropy: 0.9440
# Epoch 19/20
# 25000/25000 - 4s - loss: 1.5898e-05 - acc: 1.0000 - binary_crossentropy: 1.5898e-05 - val_loss: 0.9522 - val_acc: 0.8712 - val_binary_crossentropy: 0.9522
# Epoch 20/20
# 25000/25000 - 4s - loss: 1.4308e-05 - acc: 1.0000 - binary_crossentropy: 1.4308e-05 - val_loss: 0.9604 - val_acc: 0.8711 - val_binary_crossentropy: 0.9604

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))

  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %%
l2_model = keras.models.Sequential([
        keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                          activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
        keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                          activation=tf.nn.relu),
        keras.layers.Dense(1, activation=tf.nn.sigmoid)
    ])

l2_model.compile(loss='binary_crossentropy',
                 optimizer='adam',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20, batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 2s - loss: 0.5440 - acc: 0.7906 - binary_crossentropy: 0.5038 - val_loss: 0.3966 - val_acc: 0.8728 - val_binary_crossentropy: 0.3539
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.3175 - acc: 0.9051 - binary_crossentropy: 0.2692 - val_loss: 0.3407 - val_acc: 0.8863 - val_binary_crossentropy: 0.2884
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.2627 - acc: 0.9262 - binary_crossentropy: 0.2076 - val_loss: 0.3404 - val_acc: 0.8854 - val_binary_crossentropy: 0.2836
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.2402 - acc: 0.9370 - binary_crossentropy: 0.1817 - val_loss: 0.3542 - val_acc: 0.8813 - val_binary_crossentropy: 0.2946
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.2253 - acc: 0.9447 - binary_crossentropy: 0.1647 - val_loss: 0.3636 - val_acc: 0.8783 - val_binary_crossentropy: 0.3023
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.2136 - acc: 0.9492 - binary_crossentropy: 0.1513 - val_loss: 0.3729 - val_acc: 0.8766 - val_binary_crossentropy: 0.3104
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.2058 - acc: 0.9515 - binary_crossentropy: 0.1425 - val_loss: 0.3917 - val_acc: 0.8727 - val_binary_crossentropy: 0.3280
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.1987 - acc: 0.9542 - binary_crossentropy: 0.1344 - val_loss: 0.4020 - val_acc: 0.8728 - val_binary_crossentropy: 0.3374
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.1923 - acc: 0.9555 - binary_crossentropy: 0.1269 - val_loss: 0.4191 - val_acc: 0.8674 - val_binary_crossentropy: 0.3533
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.1870 - acc: 0.9586 - binary_crossentropy: 0.1208 - val_loss: 0.4297 - val_acc: 0.8688 - val_binary_crossentropy: 0.3631
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.1814 - acc: 0.9612 - binary_crossentropy: 0.1144 - val_loss: 0.4426 - val_acc: 0.8661 - val_binary_crossentropy: 0.3751
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.1771 - acc: 0.9612 - binary_crossentropy: 0.1092 - val_loss: 0.4596 - val_acc: 0.8635 - val_binary_crossentropy: 0.3915
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.1721 - acc: 0.9654 - binary_crossentropy: 0.1036 - val_loss: 0.4716 - val_acc: 0.8636 - val_binary_crossentropy: 0.4030
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.1692 - acc: 0.9651 - binary_crossentropy: 0.1000 - val_loss: 0.4893 - val_acc: 0.8591 - val_binary_crossentropy: 0.4199
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.1684 - acc: 0.9652 - binary_crossentropy: 0.0988 - val_loss: 0.5009 - val_acc: 0.8607 - val_binary_crossentropy: 0.4307
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.1659 - acc: 0.9665 - binary_crossentropy: 0.0947 - val_loss: 0.5161 - val_acc: 0.8570 - val_binary_crossentropy: 0.4447
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.1620 - acc: 0.9680 - binary_crossentropy: 0.0908 - val_loss: 0.5194 - val_acc: 0.8583 - val_binary_crossentropy: 0.4483
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.1571 - acc: 0.9712 - binary_crossentropy: 0.0856 - val_loss: 0.5489 - val_acc: 0.8543 - val_binary_crossentropy: 0.4774
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.1548 - acc: 0.9707 - binary_crossentropy: 0.0833 - val_loss: 0.5422 - val_acc: 0.8549 - val_binary_crossentropy: 0.4704
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.1493 - acc: 0.9747 - binary_crossentropy: 0.0775 - val_loss: 0.5521 - val_acc: 0.8546 - val_binary_crossentropy: 0.4804

# %%
plot_history([('baseline', baseline_history),
               ('l2', l2_model_history)])

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 2s - loss: 0.6117 - acc: 0.6670 - binary_crossentropy: 0.6117 - val_loss: 0.4596 - val_acc: 0.8529 - val_binary_crossentropy: 0.4596
# Epoch 2/20
# 25000/25000 - 2s - loss: 0.4279 - acc: 0.8297 - binary_crossentropy: 0.4279 - val_loss: 0.3239 - val_acc: 0.8830 - val_binary_crossentropy: 0.3239
# Epoch 3/20
# 25000/25000 - 2s - loss: 0.3274 - acc: 0.8868 - binary_crossentropy: 0.3274 - val_loss: 0.2915 - val_acc: 0.8876 - val_binary_crossentropy: 0.2915
# Epoch 4/20
# 25000/25000 - 2s - loss: 0.2740 - acc: 0.9101 - binary_crossentropy: 0.2740 - val_loss: 0.2772 - val_acc: 0.8887 - val_binary_crossentropy: 0.2772
# Epoch 5/20
# 25000/25000 - 2s - loss: 0.2342 - acc: 0.9232 - binary_crossentropy: 0.2342 - val_loss: 0.2840 - val_acc: 0.8875 - val_binary_crossentropy: 0.2840
# Epoch 6/20
# 25000/25000 - 2s - loss: 0.2032 - acc: 0.9354 - binary_crossentropy: 0.2032 - val_loss: 0.2906 - val_acc: 0.8834 - val_binary_crossentropy: 0.2906
# Epoch 7/20
# 25000/25000 - 2s - loss: 0.1800 - acc: 0.9438 - binary_crossentropy: 0.1800 - val_loss: 0.3035 - val_acc: 0.8827 - val_binary_crossentropy: 0.3035
# Epoch 8/20
# 25000/25000 - 2s - loss: 0.1593 - acc: 0.9520 - binary_crossentropy: 0.1593 - val_loss: 0.3272 - val_acc: 0.8823 - val_binary_crossentropy: 0.3272
# Epoch 9/20
# 25000/25000 - 2s - loss: 0.1459 - acc: 0.9543 - binary_crossentropy: 0.1459 - val_loss: 0.3495 - val_acc: 0.8792 - val_binary_crossentropy: 0.3495
# Epoch 10/20
# 25000/25000 - 2s - loss: 0.1261 - acc: 0.9611 - binary_crossentropy: 0.1261 - val_loss: 0.3738 - val_acc: 0.8797 - val_binary_crossentropy: 0.3738
# Epoch 11/20
# 25000/25000 - 2s - loss: 0.1188 - acc: 0.9644 - binary_crossentropy: 0.1188 - val_loss: 0.3818 - val_acc: 0.8770 - val_binary_crossentropy: 0.3818
# Epoch 12/20
# 25000/25000 - 2s - loss: 0.1081 - acc: 0.9673 - binary_crossentropy: 0.1081 - val_loss: 0.4052 - val_acc: 0.8780 - val_binary_crossentropy: 0.4052
# Epoch 13/20
# 25000/25000 - 2s - loss: 0.1014 - acc: 0.9686 - binary_crossentropy: 0.1014 - val_loss: 0.4376 - val_acc: 0.8755 - val_binary_crossentropy: 0.4376
# Epoch 14/20
# 25000/25000 - 2s - loss: 0.0933 - acc: 0.9724 - binary_crossentropy: 0.0933 - val_loss: 0.4488 - val_acc: 0.8754 - val_binary_crossentropy: 0.4488
# Epoch 15/20
# 25000/25000 - 2s - loss: 0.0862 - acc: 0.9724 - binary_crossentropy: 0.0862 - val_loss: 0.4643 - val_acc: 0.8743 - val_binary_crossentropy: 0.4643
# Epoch 16/20
# 25000/25000 - 2s - loss: 0.0796 - acc: 0.9766 - binary_crossentropy: 0.0796 - val_loss: 0.4893 - val_acc: 0.8740 - val_binary_crossentropy: 0.4893
# Epoch 17/20
# 25000/25000 - 2s - loss: 0.0768 - acc: 0.9775 - binary_crossentropy: 0.0768 - val_loss: 0.5027 - val_acc: 0.8737 - val_binary_crossentropy: 0.5027
# Epoch 18/20
# 25000/25000 - 2s - loss: 0.0710 - acc: 0.9790 - binary_crossentropy: 0.0710 - val_loss: 0.5420 - val_acc: 0.8738 - val_binary_crossentropy: 0.5420
# Epoch 19/20
# 25000/25000 - 2s - loss: 0.0692 - acc: 0.9794 - binary_crossentropy: 0.0692 - val_loss: 0.5382 - val_acc: 0.8728 - val_binary_crossentropy: 0.5382
# Epoch 20/20
# 25000/25000 - 2s - loss: 0.0650 - acc: 0.9799 - binary_crossentropy: 0.0650 - val_loss: 0.5655 - val_acc: 0.8729 - val_binary_crossentropy: 0.5655

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])

# %%
new_model = keras.models.Sequential([
        keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.01), activation=tf.nn.selu, input_shape=(NUM_WORDS,)),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.01), activation=tf.nn.relu),
        keras.layers.Dropout(0.5),
        keras.layers.Dense(1, activation=tf.nn.sigmoid)
    ])

new_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy', 'binary_crossentropy'])

new_model_history = new_model.fit(train_data, train_labels,
                                  epochs=20, batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
# 25000/25000 - 4s - loss: 0.8818 - acc: 0.6556 - binary_crossentropy: 0.6222 - val_loss: 0.6744 - val_acc: 0.8547 - val_binary_crossentropy: 0.4878
# Epoch 2/20
# 25000/25000 - 3s - loss: 0.6494 - acc: 0.8160 - binary_crossentropy: 0.4693 - val_loss: 0.5445 - val_acc: 0.8768 - val_binary_crossentropy: 0.3689
# Epoch 3/20
# 25000/25000 - 3s - loss: 0.5655 - acc: 0.8649 - binary_crossentropy: 0.3916 - val_loss: 0.5028 - val_acc: 0.8800 - val_binary_crossentropy: 0.3325
# Epoch 4/20
# 25000/25000 - 3s - loss: 0.5176 - acc: 0.8821 - binary_crossentropy: 0.3516 - val_loss: 0.4727 - val_acc: 0.8818 - val_binary_crossentropy: 0.3121
# Epoch 5/20
# 25000/25000 - 3s - loss: 0.4846 - acc: 0.8886 - binary_crossentropy: 0.3272 - val_loss: 0.4569 - val_acc: 0.8800 - val_binary_crossentropy: 0.3045
# Epoch 6/20
# 25000/25000 - 3s - loss: 0.4592 - acc: 0.8946 - binary_crossentropy: 0.3099 - val_loss: 0.4435 - val_acc: 0.8825 - val_binary_crossentropy: 0.2982
# Epoch 7/20
# 25000/25000 - 3s - loss: 0.4407 - acc: 0.8983 - binary_crossentropy: 0.2978 - val_loss: 0.4320 - val_acc: 0.8821 - val_binary_crossentropy: 0.2937
# Epoch 8/20
# 25000/25000 - 3s - loss: 0.4283 - acc: 0.8975 - binary_crossentropy: 0.2921 - val_loss: 0.4271 - val_acc: 0.8809 - val_binary_crossentropy: 0.2937
# Epoch 9/20
# 25000/25000 - 3s - loss: 0.4188 - acc: 0.9005 - binary_crossentropy: 0.2861 - val_loss: 0.4218 - val_acc: 0.8824 - val_binary_crossentropy: 0.2911
# Epoch 10/20
# 25000/25000 - 3s - loss: 0.4106 - acc: 0.9022 - binary_crossentropy: 0.2794 - val_loss: 0.4191 - val_acc: 0.8818 - val_binary_crossentropy: 0.2905
# Epoch 11/20
# 25000/25000 - 3s - loss: 0.3998 - acc: 0.9036 - binary_crossentropy: 0.2719 - val_loss: 0.4220 - val_acc: 0.8780 - val_binary_crossentropy: 0.2952
# Epoch 12/20
# 25000/25000 - 3s - loss: 0.4006 - acc: 0.9045 - binary_crossentropy: 0.2734 - val_loss: 0.4136 - val_acc: 0.8828 - val_binary_crossentropy: 0.2880
# Epoch 13/20
# 25000/25000 - 3s - loss: 0.3986 - acc: 0.8999 - binary_crossentropy: 0.2713 - val_loss: 0.4230 - val_acc: 0.8786 - val_binary_crossentropy: 0.2949
# Epoch 14/20
# 25000/25000 - 3s - loss: 0.3925 - acc: 0.9041 - binary_crossentropy: 0.2662 - val_loss: 0.4195 - val_acc: 0.8768 - val_binary_crossentropy: 0.2962
# Epoch 15/20
# 25000/25000 - 3s - loss: 0.3900 - acc: 0.9073 - binary_crossentropy: 0.2660 - val_loss: 0.4132 - val_acc: 0.8799 - val_binary_crossentropy: 0.2901
# Epoch 16/20
# 25000/25000 - 3s - loss: 0.3858 - acc: 0.9070 - binary_crossentropy: 0.2615 - val_loss: 0.4161 - val_acc: 0.8799 - val_binary_crossentropy: 0.2919
# Epoch 17/20
# 25000/25000 - 3s - loss: 0.3949 - acc: 0.9049 - binary_crossentropy: 0.2683 - val_loss: 0.4233 - val_acc: 0.8770 - val_binary_crossentropy: 0.2959
# Epoch 18/20
# 25000/25000 - 3s - loss: 0.3884 - acc: 0.9058 - binary_crossentropy: 0.2622 - val_loss: 0.4139 - val_acc: 0.8797 - val_binary_crossentropy: 0.2903
# Epoch 19/20
# 25000/25000 - 3s - loss: 0.3819 - acc: 0.9084 - binary_crossentropy: 0.2590 - val_loss: 0.4112 - val_acc: 0.8814 - val_binary_crossentropy: 0.2883
# Epoch 20/20
# 25000/25000 - 3s - loss: 0.3809 - acc: 0.9079 - binary_crossentropy: 0.2573 - val_loss: 0.4179 - val_acc: 0.8789 - val_binary_crossentropy: 0.2935

# %%
plot_history([('baseline', baseline_history),
              ('new_model', new_model_history)])
